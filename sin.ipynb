# %% [markdown]
# <a href="https://colab.research.google.com/github/JackYu2025/colab/blob/main/sin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,np.pi*2,30).round(2).tolist()
y = np.sin(x).round(2).tolist()
print(list(zip(x,y)))

fig, ax = plt.subplots()
ax.plot(x, y, marker='o', linestyle='-')
# ax.scatter(x, y, color="red", s=15)
# Out:
# [(0.0, 0.0), (0.22, 0.22), (0.43, 0.42), (0.65, 0.61), (0.87, 0.76), (1.08, 0.88), (1.3, 0.96), (1.52, 1.0), (1.73, 0.99), (1.95, 0.93), (2.17, 0.83), (2.38, 0.69), (2.6, 0.52), (2.82, 0.32), (3.03, 0.11), (3.25, -0.11), (3.47, -0.32), (3.68, -0.51), (3.9, -0.69), (4.12, -0.83), (4.33, -0.93), (4.55, -0.99), (4.77, -1.0), (4.98, -0.96), (5.2, -0.88), (5.42, -0.76), (5.63, -0.61), (5.85, -0.42), (6.07, -0.21), (6.28, -0.0)]

# %%
# !pip install mplcursors
